# %%
'''import pandas as pd
from rdkit import Chem
from rdkit.Chem import PandasTools
import random

# Define the path to the SDF file
sdf_file = 'chembl_34_sdf\chembl_34.sdf'

# Define batch size
batch_size = 1000  # Adjust this number based on your hardware capability

# Function to process molecules in batches
def process_molecules(supplier, batch_size):
    mols = []
    for i, mol in enumerate(supplier):
        if mol is not None:
            Chem.SanitizeMol(mol)
            mols.append(mol)
        if (i+1) % batch_size == 0:
            yield mols
            mols = []
    yield mols  # Yield remaining molecules

# Load the SDF file in chunks and process in batches
suppl = Chem.SDMolSupplier(sdf_file, sanitize=False)
data = []
for mols_batch in process_molecules(suppl, batch_size):
    # Randomly sample from the batch if needed
    sampled_mols = random.sample(mols_batch, min(len(mols_batch), 100))
    
    # Convert Mol objects to SMILES strings and get ChEMBL ID
    for mol in mols_batch:
        smiles = Chem.MolToSmiles(mol)
        #chembl_id = mol.GetProp('_Name')  # Get the ChEMBL ID
        data.append(smiles) #, chembl_id))
    
# Create a DataFrame with SMILES strings and ChEMBL IDs
df_smiles = pd.DataFrame(data, columns=['SMILES']) #, 'ChEMBL_ID'])
    
# Export the DataFrame with SMILES strings and ChEMBL IDs to a CSV file
df_smiles.to_csv('sampled_molecules_smiles.csv', index=False)
data = []  # Clear the data list for the next batch
'''
# Out:
# "import pandas as pd\nfrom rdkit import Chem\nfrom rdkit.Chem import PandasTools\nimport random\n\n# Define the path to the SDF file\nsdf_file = 'chembl_34_sdf\\chembl_34.sdf'\n\n# Define batch size\nbatch_size = 1000  # Adjust this number based on your hardware capability\n\n# Function to process molecules in batches\ndef process_molecules(supplier, batch_size):\n    mols = []\n    for i, mol in enumerate(supplier):\n        if mol is not None:\n            Chem.SanitizeMol(mol)\n            mols.append(mol)\n        if (i+1) % batch_size == 0:\n            yield mols\n            mols = []\n    yield mols  # Yield remaining molecules\n\n# Load the SDF file in chunks and process in batches\nsuppl = Chem.SDMolSupplier(sdf_file, sanitize=False)\ndata = []\nfor mols_batch in process_molecules(suppl, batch_size):\n    # Randomly sample from the batch if needed\n    sampled_mols = random.sample(mols_batch, min(len(mols_batch), 100))\n    \n    # Convert Mol objects to SMILES strings and get ChEMBL ID\n    for mol in mols_batch:\n        smiles = Chem.MolToSmiles(mol)\n        #chembl_id = mol.GetProp('_Name')  # Get the ChEMBL ID\n        data.append(smiles) #, chembl_id))\n    \n# Create a DataFrame with SMILES strings and ChEMBL IDs\ndf_smiles = pd.DataFrame(data, columns=['SMILES']) #, 'ChEMBL_ID'])\n    \n# Export the DataFrame with SMILES strings and ChEMBL IDs to a CSV file\ndf_smiles.to_csv('sampled_molecules_smiles.csv', index=False)\ndata = []  # Clear the data list for the next batch\n"

# %%
import pandas as pd
from rdkit import Chem,rdBase
import random
from tqdm import tqdm

# Define the path to the SDF file
sdf_file = 'chembl_34_sdf/chembl_34.sdf'

# Define the total number of molecules to sample
total_samples = 100000
rdBase.DisableLog('rdApp.warning')
# Function to process molecules in batches and sample randomly
def process_molecules_random_sample(supplier, total_samples):
    mols = []
    total_mols = sum(1 for _ in supplier)  
    supplier.reset() 
    
    sample_indices = set(random.sample(range(total_mols), total_samples))
    print("Starting molecule processing...")
    with ProgressBar(max_value=total_samples, prefix='Sampling Molecules: ') as bar:
        with rdBase.BlockLogs():  # Temporarily block RDKit logs
            for i, mol in enumerate(suppl):
                if i in sample_indices:
                    if mol is not None:
                        Chem.RemoveStereochemistry(mol)
                        try:
                            Chem.SanitizeMol(mol)
                            mols.append(mol)
                            bar.update(len(mols))  
                        except Exception as e:
                            print(f"Error sanitizing molecule {i}: {e}")
                if len(mols) >= total_samples:
                    break
            
# Load the SDF file and process molecules
suppl = Chem.SDMolSupplier(sdf_file, sanitize=False)
sampled_mols = process_molecules_random_sample(suppl, total_samples)

# Convert Mol objects to SMILES strings
data = []
for mol in sampled_mols:
    smiles = Chem.MolToSmiles(mol)
    data.append(smiles)

# Create a DataFrame with SMILES strings
df_smiles = pd.DataFrame(data, columns=['SMILES'])

# Save the DataFrame to a CSV file
df_smiles.to_csv('sampled_100k_molecules_smiles.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 37
#      35 # Load the SDF file and process molecules
#      36 suppl = Chem.SDMolSupplier(sdf_file, sanitize=False)
# ---> 37 sampled_mols = process_molecules_random_sample(suppl, total_samples)
#      39 # Convert Mol objects to SMILES strings
#      40 data = []
#
# Cell In[6], line 15, in process_molecules_random_sample(supplier, total_samples)
#      13 def process_molecules_random_sample(supplier, total_samples):
#      14     mols = []
# ---> 15     total_mols = sum(1 for _ in supplier)
#      16     supplier.reset()
#      18     sample_indices = set(random.sample(range(total_mols), total_samples))
#
# Cell In[6], line 15, in <genexpr>(.0)
#      13 def process_molecules_random_sample(supplier, total_samples):
#      14     mols = []
# ---> 15     total_mols = sum(1 for _ in supplier)
#      16     supplier.reset()
#      18     sample_indices = set(random.sample(range(total_mols), total_samples))
#
# KeyboardInterrupt:

# %%
import pandas as pd
import dask.dataframe as dd
from rdkit import Chem
from rdkit.Chem import Descriptors
from dask.distributed import Client

# Initialize Dask client
client = Client()

# Function to compute descriptors for a SMILES string
def compute_descriptors(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        descriptor_names = [desc[0] for desc in Descriptors.descList[:]]
        descriptor_values = [desc[1](mol) for desc in Descriptors.descList[:]]
        return pd.Series(descriptor_values, index=descriptor_names)
    else:
        return pd.Series([None]*len(Descriptors.descList[:]), index=[desc[0] for desc in Descriptors.descList[:]])

# Function to filter and compute descriptors for each partition
def process_partition(partition):
    partition = partition.dropna(subset=['SMILES'])
    descriptors = partition['SMILES'].apply(compute_descriptors)
    return pd.concat([partition, descriptors], axis=1)

# Read data as Dask DataFrame
dask_df = dd.read_csv('sampled_100k_molecules_smiles.csv')

# Filter out invalid SMILES and compute descriptors in parallel
processed_dask_df = dask_df.map_partitions(process_partition)

# Compute and save the result
result_df = processed_dask_df.compute()
result_df.to_csv('processed_molecule_data.csv', index=False)

# Close the Dask client
client.close()
# Out:
# c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 51497 instead
#   warnings.warn(

# %%
import pandas as pd

# Load the processed data
molecule_data_df = pd.read_csv('processed_molecule_data.csv')

# Print the columns to check the available descriptors
print(molecule_data_df.columns)
# Out:
# Index(['SMILES', 'MaxAbsEStateIndex', 'MaxEStateIndex', 'MinAbsEStateIndex',
#        'MinEStateIndex', 'qed', 'SPS', 'MolWt', 'HeavyAtomMolWt', 'ExactMolWt',
#        ...
#        'fr_sulfide', 'fr_sulfonamd', 'fr_sulfone', 'fr_term_acetylene',
#        'fr_tetrazole', 'fr_thiazole', 'fr_thiocyan', 'fr_thiophene',
#        'fr_unbrch_alkane', 'fr_urea'],
#       dtype='object', length=211)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import keras as keras

# Load the processed data
molecule_data_df = pd.read_csv('processed_molecule_data.csv')
print(molecule_data_df.isnull().sum())
# Prepare the feature matrix (exclude the SMILES column and the target column)
X = molecule_data_df.drop(columns=['SMILES', 'MaxAbsEStateIndex'])  # Adjust the target column name as needed
y = molecule_data_df['MaxAbsEStateIndex']  # Assuming 'MolWt' is the target descriptor
# Print the shapes of X and y to ensure they are not empty
print(f'X shape: {X.shape}')
print(f'y shape: {y.shape}')

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
# Out:
# SMILES               0
# MaxAbsEStateIndex    0
# MaxEStateIndex       0
# MinAbsEStateIndex    0
# MinEStateIndex       0
#                     ..
# fr_thiazole          0
# fr_thiocyan          0
# fr_thiophene         0
# fr_unbrch_alkane     0
# fr_urea              0
# Length: 211, dtype: int64
# X shape: (1, 209)
# y shape: (1,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 21
#      18 X_scaled = scaler.fit_transform(X)
#      20 # Split the data into training and testing sets
# ---> 21 X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\sklearn\model_selection\_split.py:2778, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2775 arrays = indexable(*arrays)
#    2777 n_samples = _num_samples(arrays[0])
# -> 2778 n_train, n_test = _validate_shuffle_split(
#    2779     n_samples, test_size, train_size, default_test_size=0.25
#    2780 )
#    2782 if shuffle is False:
#    2783     if stratify is not None:
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\sklearn\model_selection\_split.py:2408, in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2405 n_train, n_test = int(n_train), int(n_test)
#    2407 if n_train == 0:
# -> 2408     raise ValueError(
#    2409         "With n_samples={}, test_size={} and train_size={}, the "
#    2410         "resulting train set will be empty. Adjust any of the "
#    2411         "aforementioned parameters.".format(n_samples, test_size, train_size)
#    2412     )
#    2414 return n_train, n_test
#
# ValueError: With n_samples=1, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
# Define a simple neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Out:
# c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 17.1514 - mae: 1.8310 - val_loss: 8.8248e-04 - val_mae: 0.0129
# Epoch 2/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 3.8503e-04 - mae: 0.0087 - val_loss: 3.5363e-04 - val_mae: 0.0051
# Epoch 3/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 1.8213e-04 - mae: 0.0056 - val_loss: 2.6967e-04 - val_mae: 0.0015
# Epoch 4/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 2.3289e-04 - mae: 0.0070 - val_loss: 2.6172e-04 - val_mae: 0.0023
# Epoch 5/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 2s 994us/step - loss: 2.2337e-04 - mae: 0.0053 - val_loss: 2.5348e-04 - val_mae: 0.0019
# Epoch 6/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 2s 913us/step - loss: 2.6368e-04 - mae: 0.0067 - val_loss: 4.5198e-04 - val_mae: 0.0102
# Epoch 7/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 3.0279e-04 - mae: 0.0075 - val_loss: 4.3875e-04 - val_mae: 0.0067
# Epoch 8/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 4.5577e-04 - mae: 0.0115 - val_loss: 0.0014 - val_mae: 0.0306
# Epoch 9/50
#  866/2000 ━━━━━━━━━━━━━━━━━━━━ 1s 934us/step - loss: 3.3207e-04 - mae: 0.0096
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Train the model
# ----> 2 history = model.fit(X_train, y_train, epochs=50, validation_split=0.2, verbose=1)
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File c:\Chaitanya\ML Projects\QSAR Molecular Descriptor Prediction\.conda\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# Evaluate the model
loss, mae = model.evaluate(X_test, y_test, verbose=1)
print(f'\nFinal evaluation on test set: Loss = {loss}, MAE = {mae}')
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1477 - mae: 0.2272
#
# Final evaluation on test set: Loss = 0.14496897161006927, MAE = 0.2273031324148178

# %%
# Predict on the test set
y_pred = model.predict(X_test)
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 753us/step

# %%
# Print predicted vs actual values (optional, for a quick check)
print("\nSample predictions:")
for actual, predicted in zip(y_test, y_pred):
    print(f"Actual MolWt: {actual}, Predicted MolWt: {predicted}")
# Out:
# Sample predictions:
# Actual MolWt: 420.4610000000002, Predicted MolWt: [420.50806]
# Actual MolWt: 244.298, Predicted MolWt: [244.27133]
# Actual MolWt: 397.3970000000002, Predicted MolWt: [397.4864]
# Actual MolWt: 384.8630000000001, Predicted MolWt: [384.47208]
# Actual MolWt: 453.9710000000001, Predicted MolWt: [453.55276]
# Actual MolWt: 265.382, Predicted MolWt: [265.2452]
# Actual MolWt: 328.42, Predicted MolWt: [328.348]
# Actual MolWt: 279.33899999999994, Predicted MolWt: [279.32056]
# Actual MolWt: 436.55200000000025, Predicted MolWt: [436.44455]
# Actual MolWt: 393.4660000000002, Predicted MolWt: [393.48727]
# Actual MolWt: 179.61, Predicted MolWt: [179.34969]
# Actual MolWt: 450.5600000000002, Predicted MolWt: [450.53564]
# Actual MolWt: 363.874, Predicted MolWt: [363.46155]
# Actual MolWt: 136.14999999999998, Predicted MolWt: [136.04355]
# Actual MolWt: 291.35, Predicted MolWt: [291.3472]
# Actual MolWt: 540.6350000000003, Predicted MolWt: [540.65875]
# Actual MolWt: 267.336, Predicted MolWt: [267.31613]
# Actual MolWt: 424.66200000000015, Predicted MolWt: [423.70444]
# Actual MolWt: 379.257, Predicted MolWt: [378.51553]
# Actual MolWt: 428.8970000000001, Predicted MolWt: [428.5955]
# Actual MolWt: 348.468, Predicted MolWt: [348.3436]
# Actual MolWt: 345.49000000000007, Predicted MolWt: [345.33908]
# Actual MolWt: 339.33000000000004, Predicted MolWt: [339.5065]
# Actual MolWt: 468.3620000000002, Predicted MolWt: [468.7961]
# Actual MolWt: 344.8420000000002, Predicted MolWt: [344.38864]
# Actual MolWt: 391.4380000000001, Predicted MolWt: [391.59695]
# Actual MolWt: 352.36800000000005, Predicted MolWt: [352.4519]
# Actual MolWt: 326.38900000000007, Predicted MolWt: [326.27075]
# Actual MolWt: 475.5520000000001, Predicted MolWt: [475.65137]
# Actual MolWt: 430.57000000000016, Predicted MolWt: [430.43356]
# Actual MolWt: 420.4380000000001, Predicted MolWt: [420.61777]
# Actual MolWt: 300.34700000000004, Predicted MolWt: [300.4325]
# Actual MolWt: 608.6800000000005, Predicted MolWt: [608.77673]
# Actual MolWt: 434.74100000000016, Predicted MolWt: [435.58267]
# Actual MolWt: 1159.3349999999998, Predicted MolWt: [1159.3314]
# Actual MolWt: 617.9190000000001, Predicted MolWt: [617.4646]
# Actual MolWt: 386.81400000000014, Predicted MolWt: [386.55777]
# Actual MolWt: 269.735, Predicted MolWt: [269.3657]
# Actual MolWt: 549.1150000000004, Predicted MolWt: [548.6106]
# Actual MolWt: 499.7430000000005, Predicted MolWt: [499.41556]
# Actual MolWt: 330.46800000000013, Predicted MolWt: [330.23788]
# Actual MolWt: 497.9460000000002, Predicted MolWt: [497.7568]
# Actual MolWt: 366.45700000000016, Predicted MolWt: [366.37015]
# Actual MolWt: 313.828, Predicted MolWt: [313.3368]
# Actual MolWt: 458.6060000000001, Predicted MolWt: [458.48093]
# Actual MolWt: 255.431, Predicted MolWt: [255.14178]
# Actual MolWt: 336.34700000000004, Predicted MolWt: [336.45364]
# Actual MolWt: 597.7370000000003, Predicted MolWt: [597.7293]
# Actual MolWt: 504.56100000000026, Predicted MolWt: [504.60526]
# Actual MolWt: 490.66900000000015, Predicted MolWt: [490.51425]
# Actual MolWt: 312.51800000000003, Predicted MolWt: [312.0902]
# Actual MolWt: 332.40000000000015, Predicted MolWt: [332.3293]
# Actual MolWt: 207.258, Predicted MolWt: [207.26085]
# Actual MolWt: 376.5, Predicted MolWt: [376.37985]
# Actual MolWt: 289.806, Predicted MolWt: [289.28357]
# Actual MolWt: 437.4680000000001, Predicted MolWt: [437.66098]
# Actual MolWt: 423.4290000000001, Predicted MolWt: [423.66086]
# Actual MolWt: 363.501, Predicted MolWt: [363.3337]
# Actual MolWt: 395.4110000000001, Predicted MolWt: [395.4988]
# Actual MolWt: 314.36, Predicted MolWt: [314.45334]
# Actual MolWt: 462.4460000000002, Predicted MolWt: [462.61777]
# Actual MolWt: 308.357, Predicted MolWt: [308.3646]
# Actual MolWt: 389.4400000000001, Predicted MolWt: [389.57834]
# Actual MolWt: 501.6670000000004, Predicted MolWt: [501.48483]
# Actual MolWt: 344.3709999999999, Predicted MolWt: [344.41953]
# Actual MolWt: 868.514, Predicted MolWt: [866.079]
# Actual MolWt: 411.29200000000014, Predicted MolWt: [410.59705]
# Actual MolWt: 335.3850000000001, Predicted MolWt: [335.41336]
# Actual MolWt: 367.5440000000001, Predicted MolWt: [367.3641]
# Actual MolWt: 565.4710000000003, Predicted MolWt: [565.823]
# Actual MolWt: 507.6210000000001, Predicted MolWt: [507.55716]
# Actual MolWt: 334.37100000000004, Predicted MolWt: [334.41458]
# Actual MolWt: 308.337, Predicted MolWt: [308.39688]
# Actual MolWt: 476.6170000000002, Predicted MolWt: [476.47552]
# Actual MolWt: 742.9179999999998, Predicted MolWt: [742.80133]
# Actual MolWt: 572.6630000000005, Predicted MolWt: [572.7094]
# Actual MolWt: 435.402, Predicted MolWt: [435.6124]
# Actual MolWt: 416.48100000000017, Predicted MolWt: [416.5267]
# Actual MolWt: 229.323, Predicted MolWt: [229.18614]
# Actual MolWt: 290.36300000000006, Predicted MolWt: [290.27036]
# Actual MolWt: 236.249, Predicted MolWt: [236.2577]
# Actual MolWt: 430.38300000000015, Predicted MolWt: [429.36444]
# Actual MolWt: 401.5250000000001, Predicted MolWt: [401.3413]
# Actual MolWt: 355.55400000000014, Predicted MolWt: [355.36288]
# Actual MolWt: 466.56300000000016, Predicted MolWt: [466.57693]
# Actual MolWt: 384.3030000000001, Predicted MolWt: [384.39697]
# Actual MolWt: 345.33200000000005, Predicted MolWt: [345.50565]
# Actual MolWt: 347.4220000000001, Predicted MolWt: [347.4305]
# Actual MolWt: 435.4980000000003, Predicted MolWt: [435.49792]
# Actual MolWt: 319.383, Predicted MolWt: [319.3148]
# Actual MolWt: 267.756, Predicted MolWt: [267.2583]
# Actual MolWt: 308.271, Predicted MolWt: [308.46976]
# Actual MolWt: 417.51300000000015, Predicted MolWt: [417.4939]
# Actual MolWt: 437.28600000000006, Predicted MolWt: [437.50903]
# Actual MolWt: 541.5360000000002, Predicted MolWt: [541.7223]
# Actual MolWt: 350.42200000000014, Predicted MolWt: [350.41452]
# Actual MolWt: 347.39900000000006, Predicted MolWt: [347.50833]
# Actual MolWt: 400.294, Predicted MolWt: [399.62643]
# Actual MolWt: 361.2070000000001, Predicted MolWt: [360.56165]
# Actual MolWt: 325.32400000000007, Predicted MolWt: [325.44656]
# Actual MolWt: 270.328, Predicted MolWt: [270.27795]
# Actual MolWt: 335.77600000000007, Predicted MolWt: [335.50955]
# Actual MolWt: 592.1800000000003, Predicted MolWt: [591.6256]
# Actual MolWt: 381.867, Predicted MolWt: [381.4991]
# Actual MolWt: 434.49600000000015, Predicted MolWt: [434.53244]
# Actual MolWt: 350.4400000000002, Predicted MolWt: [350.37155]
# Actual MolWt: 461.5620000000002, Predicted MolWt: [461.5173]
# Actual MolWt: 245.307, Predicted MolWt: [245.31628]
# Actual MolWt: 405.4940000000001, Predicted MolWt: [405.44504]
# Actual MolWt: 372.8570000000002, Predicted MolWt: [372.39926]
# Actual MolWt: 323.44300000000004, Predicted MolWt: [323.37082]
# Actual MolWt: 1333.633999999999, Predicted MolWt: [1333.2893]
# Actual MolWt: 455.5620000000001, Predicted MolWt: [455.5493]
# Actual MolWt: 343.74500000000006, Predicted MolWt: [343.53165]
# Actual MolWt: 466.9720000000001, Predicted MolWt: [466.64145]
# Actual MolWt: 572.6590000000002, Predicted MolWt: [572.6152]
# Actual MolWt: 280.371, Predicted MolWt: [280.28772]
# Actual MolWt: 233.311, Predicted MolWt: [233.18968]
# Actual MolWt: 414.8110000000001, Predicted MolWt: [414.5759]
# Actual MolWt: 380.4, Predicted MolWt: [380.57132]
# Actual MolWt: 430.4210000000001, Predicted MolWt: [430.5764]
# Actual MolWt: 474.63000000000017, Predicted MolWt: [474.54758]
# Actual MolWt: 424.8840000000001, Predicted MolWt: [424.55542]
# Actual MolWt: 642.275, Predicted MolWt: [641.62775]
# Actual MolWt: 421.4970000000002, Predicted MolWt: [421.48633]
# Actual MolWt: 230.31099999999995, Predicted MolWt: [230.20567]
# Actual MolWt: 425.5540000000003, Predicted MolWt: [425.47397]
# Actual MolWt: 356.4470000000001, Predicted MolWt: [356.41907]
# Actual MolWt: 256.22099999999995, Predicted MolWt: [256.40274]
# Actual MolWt: 478.39800000000014, Predicted MolWt: [477.62497]
# Actual MolWt: 373.38800000000015, Predicted MolWt: [373.48996]
# Actual MolWt: 305.38800000000003, Predicted MolWt: [305.42862]
# Actual MolWt: 417.9620000000002, Predicted MolWt: [417.4836]
# Actual MolWt: 380.52800000000025, Predicted MolWt: [380.3199]
# Actual MolWt: 541.5280000000004, Predicted MolWt: [541.7036]
# Actual MolWt: 352.3900000000002, Predicted MolWt: [352.43137]
# Actual MolWt: 428.44100000000014, Predicted MolWt: [428.52628]
# Actual MolWt: 493.45300000000026, Predicted MolWt: [493.58334]
# Actual MolWt: 327.47500000000014, Predicted MolWt: [327.322]
# Actual MolWt: 261.321, Predicted MolWt: [261.32956]
# Actual MolWt: 463.5410000000002, Predicted MolWt: [463.61337]
# Actual MolWt: 168.23599999999996, Predicted MolWt: [168.04546]
# Actual MolWt: 303.36600000000004, Predicted MolWt: [303.3276]
# Actual MolWt: 459.9150000000001, Predicted MolWt: [459.65842]
# Actual MolWt: 323.44000000000005, Predicted MolWt: [323.3138]
# Actual MolWt: 496.55600000000015, Predicted MolWt: [496.55054]
# Actual MolWt: 246.27, Predicted MolWt: [246.29932]
# Actual MolWt: 396.45100000000014, Predicted MolWt: [396.48813]
# Actual MolWt: 371.5280000000002, Predicted MolWt: [371.3565]
# Actual MolWt: 462.96200000000016, Predicted MolWt: [462.65848]
# Actual MolWt: 356.49200000000013, Predicted MolWt: [356.30942]
# Actual MolWt: 335.39200000000005, Predicted MolWt: [335.4928]
# Actual MolWt: 426.50200000000007, Predicted MolWt: [426.6401]
# Actual MolWt: 277.3280000000001, Predicted MolWt: [277.2988]
# Actual MolWt: 464.5470000000002, Predicted MolWt: [464.6013]
# Actual MolWt: 491.55400000000014, Predicted MolWt: [491.56876]
# Actual MolWt: 408.45700000000016, Predicted MolWt: [408.56094]
# Actual MolWt: 551.6470000000002, Predicted MolWt: [551.6937]
# Actual MolWt: 313.44500000000005, Predicted MolWt: [313.2628]
# Actual MolWt: 353.4180000000001, Predicted MolWt: [353.38748]
# Actual MolWt: 338.338, Predicted MolWt: [338.47583]
# Actual MolWt: 842.9879999999999, Predicted MolWt: [842.881]
# Actual MolWt: 357.385, Predicted MolWt: [357.44876]
# Actual MolWt: 355.3930000000001, Predicted MolWt: [355.4838]
# Actual MolWt: 514.6480000000003, Predicted MolWt: [514.5626]
# Actual MolWt: 1342.5270000000005, Predicted MolWt: [1342.648]
# Actual MolWt: 567.5990000000003, Predicted MolWt: [567.708]
# Actual MolWt: 330.91, Predicted MolWt: [330.34982]
# Actual MolWt: 383.4770000000003, Predicted MolWt: [383.47852]
# Actual MolWt: 416.837, Predicted MolWt: [416.68796]
# Actual MolWt: 320.3700000000001, Predicted MolWt: [320.3916]
# Actual MolWt: 443.54700000000014, Predicted MolWt: [443.51163]
# Actual MolWt: 389.8050000000001, Predicted MolWt: [389.51422]
# Actual MolWt: 318.42, Predicted MolWt: [318.3431]
# Actual MolWt: 563.6810000000004, Predicted MolWt: [563.7258]
# Actual MolWt: 405.5160000000001, Predicted MolWt: [405.41318]
# Actual MolWt: 379.3790000000001, Predicted MolWt: [379.6116]
# Actual MolWt: 400.9060000000002, Predicted MolWt: [400.4498]
# Actual MolWt: 276.248, Predicted MolWt: [276.37296]
# Actual MolWt: 403.51100000000014, Predicted MolWt: [403.5282]
# Actual MolWt: 296.3880000000001, Predicted MolWt: [296.2749]
# Actual MolWt: 351.38700000000006, Predicted MolWt: [351.51187]
# Actual MolWt: 302.42200000000014, Predicted MolWt: [302.2557]
# Actual MolWt: 410.4010000000001, Predicted MolWt: [410.56717]
# Actual MolWt: 729.9189999999998, Predicted MolWt: [729.7551]
# Actual MolWt: 583.611, Predicted MolWt: [583.8563]
# Actual MolWt: 267.24499999999995, Predicted MolWt: [267.35254]
# Actual MolWt: 392.49900000000014, Predicted MolWt: [392.41]
# Actual MolWt: 317.7760000000001, Predicted MolWt: [317.40378]
# Actual MolWt: 482.4950000000002, Predicted MolWt: [482.686]
# Actual MolWt: 412.358938, Predicted MolWt: [411.46176]
# Actual MolWt: 248.19, Predicted MolWt: [248.35745]
# Actual MolWt: 330.7750000000001, Predicted MolWt: [330.44998]
# Actual MolWt: 430.4470000000001, Predicted MolWt: [430.65012]
# Actual MolWt: 238.159, Predicted MolWt: [238.38103]
# Actual MolWt: 536.0130000000003, Predicted MolWt: [535.7692]
# Actual MolWt: 415.5740000000003, Predicted MolWt: [415.32294]
# Actual MolWt: 328.408, Predicted MolWt: [328.31467]
# Actual MolWt: 378.41000000000014, Predicted MolWt: [378.4918]
# Actual MolWt: 494.5280000000001, Predicted MolWt: [494.55536]
# Actual MolWt: 338.41099999999994, Predicted MolWt: [338.3879]
# Actual MolWt: 606.7270000000002, Predicted MolWt: [606.74646]
# Actual MolWt: 401.9410000000001, Predicted MolWt: [401.48532]
# Actual MolWt: 328.4160000000001, Predicted MolWt: [328.33688]
# Actual MolWt: 314.37, Predicted MolWt: [314.42355]
# Actual MolWt: 338.4510000000001, Predicted MolWt: [338.32446]
# Actual MolWt: 353.3040000000002, Predicted MolWt: [352.31357]
# Actual MolWt: 413.5140000000002, Predicted MolWt: [413.39975]
# Actual MolWt: 462.6530000000002, Predicted MolWt: [462.41522]
# Actual MolWt: 372.472, Predicted MolWt: [372.4398]
# Actual MolWt: 537.0600000000003, Predicted MolWt: [536.6364]
# Actual MolWt: 345.40600000000006, Predicted MolWt: [345.45496]
# Actual MolWt: 234.255, Predicted MolWt: [234.26158]
# Actual MolWt: 501.55300000000034, Predicted MolWt: [501.6309]
# Actual MolWt: 418.3200000000001, Predicted MolWt: [417.52112]
# Actual MolWt: 366.42800000000005, Predicted MolWt: [366.52417]
# Actual MolWt: 560.7760000000002, Predicted MolWt: [560.4203]
# Actual MolWt: 393.54100000000005, Predicted MolWt: [393.51367]
# Actual MolWt: 537.0120000000003, Predicted MolWt: [536.7608]
# Actual MolWt: 632.6300000000005, Predicted MolWt: [632.8606]
# Actual MolWt: 767.9310000000003, Predicted MolWt: [767.9424]
# Actual MolWt: 362.4140000000001, Predicted MolWt: [362.53006]
# Actual MolWt: 436.51200000000017, Predicted MolWt: [436.50806]
# Actual MolWt: 507.5020000000002, Predicted MolWt: [507.75296]
# Actual MolWt: 545.6620000000004, Predicted MolWt: [545.61444]
# Actual MolWt: 416.5210000000002, Predicted MolWt: [416.46323]
# Actual MolWt: 347.2300000000001, Predicted MolWt: [346.54935]
# Actual MolWt: 384.3960000000001, Predicted MolWt: [384.51392]
# Actual MolWt: 408.5490000000003, Predicted MolWt: [408.4559]
# Actual MolWt: 616.7560000000003, Predicted MolWt: [616.59735]
# Actual MolWt: 244.338, Predicted MolWt: [244.20784]
# Actual MolWt: 335.4360000000001, Predicted MolWt: [335.44046]
# Actual MolWt: 435.8750000000001, Predicted MolWt: [435.6482]
# Actual MolWt: 865.0879999999999, Predicted MolWt: [864.9906]
# Actual MolWt: 389.3810000000001, Predicted MolWt: [389.56097]
# Actual MolWt: 308.37800000000004, Predicted MolWt: [308.2761]
# Actual MolWt: 468.59000000000026, Predicted MolWt: [468.44138]
# Actual MolWt: 308.85300000000007, Predicted MolWt: [308.25644]
